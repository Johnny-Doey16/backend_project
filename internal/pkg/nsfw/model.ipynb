# %%
import tensorflow as tf
import numpy as np

# %%
# python3 -m pip install --upgrade opennsfw2
import opennsfw2 as on

# !pip install opennsfw2
# Out:
# Using TensorFlow backend
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/macbook/Projects/Tamitrix/diivix_backend/internal/pkg/nsfw/model.ipynb Cell 2 line 2
#       <a href='vscode-notebook-cell:/Users/macbook/Projects/Tamitrix/diivix_backend/internal/pkg/nsfw/model.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> # python3 -m pip install --upgrade opennsfw2
# ----> <a href='vscode-notebook-cell:/Users/macbook/Projects/Tamitrix/diivix_backend/internal/pkg/nsfw/model.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> import opennsfw2 as on
#       <a href='vscode-notebook-cell:/Users/macbook/Projects/Tamitrix/diivix_backend/internal/pkg/nsfw/model.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> # !pip install opennsfw2
#
# File /opt/homebrew/lib/python3.11/site-packages/opennsfw2/__init__.py:4
#       2 from ._image import Preprocessing as Preprocessing
# ...
